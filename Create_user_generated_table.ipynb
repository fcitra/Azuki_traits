# %%
import pandas as pd

# %%
import sqlite3

# %%
azuki_traits = pd.read_csv("https://raw.githubusercontent.com/fcitra/Azuki_traits/main/azuki_traits_with_gender_df.csv")

# %%
azuki_traits.columns
# Out:
# Index(['Unnamed: 0', 'Token_id', 'Two categories', 'Hair', 'Clothing',
#        'Background', 'Mouth', 'Offhand', 'Type', 'Eyes', 'Trait_count', 'Ear',
#        'Neck', 'Headgear', 'Face', 'Special'],
#       dtype='object')

# %%
azuki_traits = azuki_traits.drop('Unnamed: 0', axis=1)

# %%
azuki_traits = azuki_traits.fillna('None')

# %%
azuki_traits.dtypes
# Out:
# Token_id           int64
# Two categories    object
# Hair              object
# Clothing          object
# Background        object
# Mouth             object
# Offhand           object
# Type              object
# Eyes              object
# Trait_count        int64
# Ear               object
# Neck              object
# Headgear          object
# Face              object
# Special           object
# dtype: object

# %%
azuki_traits['Token_id'].head()
# Out:
# 0    0
# 1    1
# 2    2
# 3    3
# 4    4
# Name: Token_id, dtype: int64

# %%
azuki_traits['Token_id'] = azuki_traits['Token_id'].apply(str)

# %%
azuki_traits['Trait_count'] = azuki_traits['Trait_count'].apply(str)

# %%
azuki_traits.dtypes
# Out:
# Token_id          object
# Two categories    object
# Hair              object
# Clothing          object
# Background        object
# Mouth             object
# Offhand           object
# Type              object
# Eyes              object
# Trait_count       object
# Ear               object
# Neck              object
# Headgear          object
# Face              object
# Special           object
# dtype: object

# %%
conn = sqlite3.connect('test_database')
c = conn.cursor()

# %%
c.execute('CREATE TABLE IF NOT EXISTS products (product_name text, price number)')
conn.commit()

# %%
azuki_traits.to_sql('products', conn, if_exists='replace', index = False)
 
c.execute('''  
SELECT * FROM products
          ''')

y = c.fetchall()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py:2882: UserWarning: The spaces in these column names will not be changed. In pandas versions < 0.14, spaces were converted to underscores.
#   method=method,

# %%
k = y[1:5]

# %%
for i in range(5000,10000):
    print (y[i],',')
# Out:
# ('5000', 'M', 'Maroon Half Bun', 'Maroon Yukata', 'Off White A', 'Chuckle', 'Water Orb', 'Red', 'Bored', '7', 'None', 'None', 'None', 'None', 'None') ,
# ('5001', 'M', 'Silver Dreadlocks', 'White Layered Yukata', 'Off White A', 'Smirk', 'None', 'Human', 'Meditating', '6', 'None', 'None', 'None', 'None', 'None') ,
# ('5002', 'M', 'Blonde Short Spiky', 'Black Tech Jacket', 'Off White C', 'Face Mask', 'None', 'Human', 'Suspicious', '6', 'None', 'None', 'None', 'None', 'None') ,
# ('5003', 'M', 'Silver Swept Back', 'Frog Yukata', 'Off White D', 'Grass', 'Floorsweeper', 'Blue', 'Tired', '7', 'None', 'None', 'None', 'None', 'None') ,
# ('5004', 'M', 'Pink Samurai', 'Light Kimono', 'Off White D', 'Pout', 'Boombox', 'Human', 'Curious', '7', 'None', 'None', 'None', 'None', 'None') ,
# ('5005', 'M', 'Black Fluffy', 'Fur Hoodie', 'Off White C', 'Chuckle', 'Floorsweeper', 'Human', 'Careless', '8', 'Red Panda', 'None', 'None', 'None', 'None') ,
# ...
